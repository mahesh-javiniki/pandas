# %% [markdown]
# # **Data Selection & Indexing**

# %% [markdown]
# ## Practice with Titanic dataset

# %%
import pandas as pd
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## **1. Basic Selection Techniques**

# %%
titanic['survived'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: survived, dtype: int64

# %%
titanic[['survived', 'sex', 'age']].head()
# Out:
#    survived     sex   age
# 0         0    male  22.0
# 1         1  female  38.0
# 2         1  female  26.0
# 3         1  female  35.0
# 4         0    male  35.0

# %%
titanic.loc[1]
# Out:
# survived               1
# pclass                 1
# sex               female
# age                 38.0
# sibsp                  1
# parch                  0
# fare             71.2833
# embarked               C
# class              First
# who                woman
# adult_male         False
# deck                   C
# embark_town    Cherbourg
# alive                yes
# alone              False
# Name: 1, dtype: object

# %%
titanic.loc[[1, 3]]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 3  woman       False    C  Southampton   yes  False

# %%
titanic.iloc[1]
# Out:
# survived               1
# pclass                 1
# sex               female
# age                 38.0
# sibsp                  1
# parch                  0
# fare             71.2833
# embarked               C
# class              First
# who                woman
# adult_male         False
# deck                   C
# embark_town    Cherbourg
# alive                yes
# alone              False
# Name: 1, dtype: object

# %%
titanic.iloc[[1, 3]]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 3  woman       False    C  Southampton   yes  False

# %%
# slicing
titanic[1: 5]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic[1: 5: 2]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 3  woman       False    C  Southampton   yes  False

# %%
titanic.loc[1: 5, 'survived']
# Out:
# 1    1
# 2    1
# 3    1
# 4    0
# 5    0
# Name: survived, dtype: int64

# %%
titanic.loc[1: 5, 'survived': 'fare']
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500
# 5         0       3    male   NaN      0      0   8.4583

# %%
titanic.loc[1: 5, ['survived', 'fare']]
# Out:
#    survived     fare
# 1         1  71.2833
# 2         1   7.9250
# 3         1  53.1000
# 4         0   8.0500
# 5         0   8.4583

# %% [markdown]
# ## 2. **Indexing and Reindexing**

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic1 = titanic.set_index('survived')
titanic1.head()
# Out:
#           pclass     sex   age  sibsp  parch     fare embarked  class    who  \
# survived
# 0              3    male  22.0      1      0   7.2500        S  Third    man
# 1              1  female  38.0      1      0  71.2833        C  First  woman
# 1              3  female  26.0      0      0   7.9250        S  Third  woman
# 1              1  female  35.0      1      0  53.1000        S  First  woman
# 0              3    male  35.0      0      0   8.0500        S  Third    man
#
#           adult_male deck  embark_town alive  alone
# survived
# 0               True  NaN  Southampton    no  False
# 1              False    C    Cherbourg   yes  False
# 1              False  NaN  Southampton   yes   True
# 1              False    C  Southampton   yes  False
# 0               True  NaN  Southampton    no   True

# %%
titanic1.loc[1]
# Out:
#           pclass     sex   age  sibsp  parch     fare embarked   class    who  \
# survived
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 1              3  female  26.0      0      0   7.9250        S   Third  woman
# 1              1  female  35.0      1      0  53.1000        S   First  woman
# 1              3  female  27.0      0      2  11.1333        S   Third  woman
# 1              2  female  14.0      1      0  30.0708        C  Second  child
# ...          ...     ...   ...    ...    ...      ...      ...     ...    ...
# 1              3  female  15.0      0      0   7.2250        C   Third  child
# 1              1  female  56.0      0      1  83.1583        C   First  woman
# 1              2  female  25.0      0      1  26.0000        S  Second  woman
# 1              1  female  19.0      0      0  30.0000        S   First  woman
# 1              1    male  26.0      0      0  30.0000        C   First    man
#
# ...

# %%
titanic1.reset_index()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.index = titanic['survived']

# %%
titanic.head()
# Out:
#           survived  pclass     sex   age  sibsp  parch     fare embarked  \
# survived
# 0                0       3    male  22.0      1      0   7.2500        S
# 1                1       1  female  38.0      1      0  71.2833        C
# 1                1       3  female  26.0      0      0   7.9250        S
# 1                1       1  female  35.0      1      0  53.1000        S
# 0                0       3    male  35.0      0      0   8.0500        S
#
#           class    who  adult_male deck  embark_town alive  alone
# survived
# 0         Third    man        True  NaN  Southampton    no  False
# 1         First  woman       False    C    Cherbourg   yes  False
# 1         Third  woman       False  NaN  Southampton   yes   True
# 1         First  woman       False    C  Southampton   yes  False
# 0         Third    man        True  NaN  Southampton    no   True

# %%
titanic.reset_index(drop=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Hierarchical indexing

titanic.set_index(['sex', 'survived'])
# Out:
#                  pclass   age  sibsp  parch     fare embarked   class    who  \
# sex    survived
# male   0              3  22.0      1      0   7.2500        S   Third    man
# female 1              1  38.0      1      0  71.2833        C   First  woman
#        1              3  26.0      0      0   7.9250        S   Third  woman
#        1              1  35.0      1      0  53.1000        S   First  woman
# male   0              3  35.0      0      0   8.0500        S   Third    man
# ...                 ...   ...    ...    ...      ...      ...     ...    ...
#        0              2  27.0      0      0  13.0000        S  Second    man
# female 1              1  19.0      0      0  30.0000        S   First  woman
#        0              3   NaN      1      2  23.4500        S   Third  woman
# male   1              1  26.0      0      0  30.0000        C   First    man
#        0              3  32.0      0      0   7.7500        Q   Third    man
#
# ...

# %% [markdown]
# <center><b>Thanks</b></center>
