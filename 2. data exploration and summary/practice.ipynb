# %% [markdown]
# # Data Exploration and Summary

# %% [markdown]
# ## Practice with Titanic dataset

# %%
import pandas as pd
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## 1. Data Overview

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
titanic.select_dtypes(include='number').columns
# Out:
# Index(['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare'], dtype='object')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.memory_usage()
# Out:
# Index           128
# survived       7128
# pclass         7128
# sex            7128
# age            7128
# sibsp          7128
# parch          7128
# fare           7128
# embarked       7128
# class          1023
# who            7128
# adult_male      891
# deck           1247
# embark_town    7128
# alive          7128
# alone           891
# dtype: int64

# %%
titanic.memory_usage().sum()
# Out:
# 82588

# %%
titanic.sample(3)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 235         0       3  female   NaN      0      0   7.5500        S  Third
# 349         0       3    male  42.0      0      0   8.6625        S  Third
# 353         0       3    male  25.0      1      0  17.8000        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 235  woman       False  NaN  Southampton    no   True
# 349    man        True  NaN  Southampton    no   True
# 353    man        True  NaN  Southampton    no  False

# %%
titanic.sample(frac=0.01)
# Out:
#      survived  pclass     sex    age  sibsp  parch    fare embarked   class  \
# 119         0       3  female   2.00      4      2  31.275        S   Third
# 414         1       3    male  44.00      0      0   7.925        S   Third
# 78          1       2    male   0.83      0      2  29.000        S  Second
# 801         1       2  female  31.00      1      1  26.250        S  Second
# 178         0       2    male  30.00      0      0  13.000        S  Second
# 736         0       3  female  48.00      1      3  34.375        S   Third
# 116         0       3    male  70.50      0      0   7.750        Q   Third
# 809         1       1  female  33.00      1      0  53.100        S   First
# 624         0       3    male  21.00      0      0  16.100        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 119  child       False  NaN  Southampton    no  False
# 414    man        True  NaN  Southampton   yes   True
# ...

# %% [markdown]
# ## Summary Statistics

# %%
titanic.mean(numeric_only=True)
# Out:
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
titanic.median(numeric_only=True)
# Out:
# survived       0.0000
# pclass         3.0000
# age           28.0000
# sibsp          0.0000
# parch          0.0000
# fare          14.4542
# adult_male     1.0000
# alone          1.0000
# dtype: float64

# %%
titanic.mode()
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  24.0      0      0  8.05        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True    C  Southampton    no   True

# %%
titanic.min(numeric_only=True)
# Out:
# survived          0
# pclass            1
# age            0.42
# sibsp             0
# parch             0
# fare            0.0
# adult_male    False
# alone         False
# dtype: object

# %%
titanic.max(numeric_only=True)
# Out:
# survived             1
# pclass               3
# age               80.0
# sibsp                8
# parch                6
# fare          512.3292
# adult_male        True
# alone             True
# dtype: object

# %%
titanic.std(numeric_only=True)
# Out:
# survived       0.486592
# pclass         0.836071
# age           14.526497
# sibsp          1.102743
# parch          0.806057
# fare          49.693429
# adult_male     0.489615
# alone          0.489615
# dtype: float64

# %%
titanic.var(numeric_only=True)
# Out:
# survived         0.236772
# pclass           0.699015
# age            211.019125
# sibsp            1.216043
# parch            0.649728
# fare          2469.436846
# adult_male       0.239723
# alone            0.239723
# dtype: float64

# %%
titanic.sem(numeric_only=True)
# Out:
# survived      0.016301
# pclass        0.028009
# age           0.543640
# sibsp         0.036943
# parch         0.027004
# fare          1.664792
# adult_male    0.016403
# alone         0.016403
# dtype: float64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.select_dtypes(include='number')
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3   NaN      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
titanic.select_dtypes(include='number').quantile(0.25)
# Out:
# survived     0.0000
# pclass       2.0000
# age         20.1250
# sibsp        0.0000
# parch        0.0000
# fare         7.9104
# Name: 0.25, dtype: float64

# %%
titanic.select_dtypes(include='number').quantile(0.35)
# Out:
# survived     0.0
# pclass       2.0
# age         24.0
# sibsp        0.0
# parch        0.0
# fare         9.0
# Name: 0.35, dtype: float64

# %%
titanic.select_dtypes(include='number').cumsum()
# Out:
#      survived  pclass       age  sibsp  parch        fare
# 0           0       3     22.00      1      0      7.2500
# 1           1       4     60.00      2      0     78.5333
# 2           2       7     86.00      2      0     86.4583
# 3           3       8    121.00      3      0    139.5583
# 4           3      11    156.00      3      0    147.6083
# ..        ...     ...       ...    ...    ...         ...
# 886       340    2049  21128.17    465    338  28602.7493
# 887       341    2050  21147.17    465    338  28632.7493
# 888       341    2053       NaN    466    340  28656.1993
# 889       342    2054  21173.17    466    340  28686.1993
# 890       342    2057  21205.17    466    340  28693.9493
#
# [891 rows x 6 columns]

# %%
titanic.select_dtypes(include='number').cumprod()
# Out:
# c:\Python310\lib\site-packages\numpy\core\fromnumeric.py:59: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
#      survived  pclass         age  sibsp  parch          fare
# 0           0       3        22.0      1      0  7.250000e+00
# 1           0       3       836.0      1      0  5.168039e+02
# 2           0       9     21736.0      0      0  4.095671e+03
# 3           0       9    760760.0      0      0  2.174801e+05
# 4           0      27  26626600.0      0      0  1.750715e+06
# ..        ...     ...         ...    ...    ...           ...
# 886         0       0         inf      0      0  0.000000e+00
# 887         0       0         inf      0      0  0.000000e+00
# 888         0       0         NaN      0      0  0.000000e+00
# 889         0       0         inf      0      0  0.000000e+00
# 890         0       0         inf      0      0  0.000000e+00
#
# [891 rows x 6 columns]

# %% [markdown]
# ## 3. Value Counts & Frequency Analysis

# %%
titanic['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
titanic.who.value_counts()
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %%
titanic.value_counts(['sex', 'who'])
# Out:
# sex     who
# male    man      537
# female  woman    271
#         child     43
# male    child     40
# Name: count, dtype: int64

# %%
titanic.value_counts(['sex', 'embarked', 'who', 'embark_town', 'alive'])
# Out:
# sex     embarked  who    embark_town  alive
# male    S         man    Southampton  no       351
# female  S         woman  Southampton  yes      124
# male    C         man    Cherbourg    no        64
#         S         man    Southampton  yes       59
# female  C         woman  Cherbourg    yes       53
#         S         woman  Southampton  no        50
# male    Q         man    Queenstown   no        34
# female  Q         woman  Queenstown   yes       26
# male    C         man    Cherbourg    yes       26
#         S         child  Southampton  yes       18
# female  S         child  Southampton  yes       16
#                                       no        13
# male    S         child  Southampton  no        13
# female  C         child  Cherbourg    yes       11
#         Q         woman  Queenstown   no         9
#         C         woman  Cherbourg    no         7
# male    Q         child  Queenstown   no         4
#         C         child  Cherbourg    yes        3
# ...

# %%
titanic.sex.value_counts(normalize=True) * 100
# Out:
# sex
# male      64.758698
# female    35.241302
# Name: proportion, dtype: float64

# %%
titanic.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
try:
    print(titanic[['sex', 'who']].unique())
except Exception as e:
    print(e)
# Out:
# 'DataFrame' object has no attribute 'unique'

# %%
titanic.who.nunique()
# Out:
# 3

# %% [markdown]
# ## Data Type Summary

# %%
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
titanic.select_dtypes(include='number').head(2)
# Out:
#    survived  pclass   age  sibsp  parch     fare
# 0         0       3  22.0      1      0   7.2500
# 1         1       1  38.0      1      0  71.2833

# %%
titanic.select_dtypes(exclude='number').head(2)
# Out:
#       sex embarked  class    who  adult_male deck  embark_town alive  alone
# 0    male        S  Third    man        True  NaN  Southampton    no  False
# 1  female        C  First  woman       False    C    Cherbourg   yes  False

# %%
titanic.select_dtypes(include='category').head(2)
# Out:
#    class deck
# 0  Third  NaN
# 1  First    C

# %%
titanic.select_dtypes(include=['number', 'category']).head()
# Out:
#    survived  pclass   age  sibsp  parch     fare  class deck
# 0         0       3  22.0      1      0   7.2500  Third  NaN
# 1         1       1  38.0      1      0  71.2833  First    C
# 2         1       3  26.0      0      0   7.9250  Third  NaN
# 3         1       1  35.0      1      0  53.1000  First    C
# 4         0       3  35.0      0      0   8.0500  Third  NaN

# %%
titanic['deck'].value_counts()
# Out:
# deck
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: count, dtype: int64

# %%
titanic['deck'].dtype
# Out:
# CategoricalDtype(categories=['A', 'B', 'C', 'D', 'E', 'F', 'G'], ordered=False, categories_dtype=object)

# %%
titanic['who'].value_counts()
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %%
titanic['who'].dtype
# Out:
# dtype('O')

# %%
titanic['who'] = titanic['who'].astype('category')

# %%
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who            category
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
titanic.who.dtype
# Out:
# CategoricalDtype(categories=['child', 'man', 'woman'], ordered=False, categories_dtype=object)

# %% [markdown]
# ## 4. Inference & Conversion Utilities

# %%
df = pd.DataFrame({
    'bool_column': [True, False, True, True, False]
})

# Convert using pd.to_numeric
df['int_column'] = pd.to_numeric(df['bool_column'])

print(df)
# Out:
#    bool_column  int_column
# 0         True        True
# 1        False       False
# 2         True        True
# 3         True        True
# 4        False       False

# %%
df = pd.DataFrame({
    'bool_column': [True, False, True, True, False]
})

df['int_column'] = df['bool_column'].astype(int)

print(df)
print(df.dtypes)
# Out:
#    bool_column  int_column
# 0         True           1
# 1        False           0
# 2         True           1
# 3         True           1
# 4        False           0
# bool_column     bool
# int_column     int32
# dtype: object

# %%
titanic.alone = titanic.alone.astype('int')

# %%
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who            category
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone             int32
# dtype: object

# %%
titanic.survived.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: survived, dtype: int64

# %%
titanic.survived = titanic.survived.astype('bool')

# %%
titanic.survived.head()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# Name: survived, dtype: bool

# %%
titanic.dtypes
# Out:
# survived           bool
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who            category
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone             int32
# dtype: object

# %% [markdown]
# ## Correlation & Covariance

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0     False       3    male  22.0      1      0   7.2500        S  Third
# 1      True       1  female  38.0      1      0  71.2833        C  First
# 2      True       3  female  26.0      0      0   7.9250        S  Third
# 3      True       1  female  35.0      1      0  53.1000        S  First
# 4     False       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no      0
# 1  woman       False    C    Cherbourg   yes      0
# 2  woman       False  NaN  Southampton   yes      1
# 3  woman       False    C  Southampton   yes      0
# 4    man        True  NaN  Southampton    no      1

# %%
titanic.corr(numeric_only=True)
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(titanic.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %%
titanic.cov(numeric_only=True)
# Out:
#             survived     pclass         age     sibsp     parch         fare  \
# survived    0.236772  -0.137703   -0.551296 -0.018954  0.032017     6.221787
# pclass     -0.137703   0.699015   -4.496004  0.076599  0.012429   -22.830196
# age        -0.551296  -4.496004  211.019125 -4.163334 -2.344191    73.849030
# sibsp      -0.018954   0.076599   -4.163334  1.216043  0.368739     8.748734
# parch       0.032017   0.012429   -2.344191  0.368739  0.649728     8.661052
# fare        6.221787 -22.830196   73.849030  8.748734  8.661052  2469.436846
# adult_male -0.132720   0.038494    2.012292 -0.136916 -0.138108    -4.428757
# alone      -0.048451   0.055347    1.428550 -0.315568 -0.230242    -6.613861
#
#             adult_male     alone
# survived     -0.132720 -0.048451
# pclass        0.038494  0.055347
# age           2.012292  1.428550
# sibsp        -0.136916 -0.315568
# parch        -0.138108 -0.230242
# fare         -4.428757 -6.613861
# adult_male    0.239723  0.097026
# ...

# %% [markdown]
# ## 6. Missing Data Summary in pandas

# %%
titanic.isna().head()
# Out:
#    survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0     False   False  False  False  False  False  False     False  False
# 1     False   False  False  False  False  False  False     False  False
# 2     False   False  False  False  False  False  False     False  False
# 3     False   False  False  False  False  False  False     False  False
# 4     False   False  False  False  False  False  False     False  False
#
#      who  adult_male   deck  embark_town  alive  alone
# 0  False       False   True        False  False  False
# 1  False       False  False        False  False  False
# 2  False       False   True        False  False  False
# 3  False       False  False        False  False  False
# 4  False       False   True        False  False  False

# %%
titanic.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic.notna().sum()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    bool
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    category
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    int32
# dtypes: bool(2), category(3), float64(2), int32(1), int64(3), object(4)
# memory usage: 71.2+ KB

# %% [markdown]
# ### droping NaN values

# %%
titanic.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1        True       1  female  38.0      1      0  71.2833        C  First
# 3        True       1  female  35.0      1      0  53.1000        S  First
# 6       False       1    male  54.0      0      0  51.8625        S  First
# 10       True       3  female   4.0      1      1  16.7000        S  Third
# 11       True       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871      True       1  female  47.0      1      1  52.5542        S  First
# 872     False       1    male  33.0      0      0   5.0000        S  First
# 879      True       1  female  56.0      0      1  83.1583        C  First
# 887      True       1  female  19.0      0      0  30.0000        S  First
# 889      True       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.dropna(subset=['age'])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0       False       3    male  22.0      1      0   7.2500        S   Third
# 1        True       1  female  38.0      1      0  71.2833        C   First
# 2        True       3  female  26.0      0      0   7.9250        S   Third
# 3        True       1  female  35.0      1      0  53.1000        S   First
# 4       False       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885     False       3  female  39.0      0      5  29.1250        Q   Third
# 886     False       2    male  27.0      0      0  13.0000        S  Second
# 887      True       1  female  19.0      0      0  30.0000        S   First
# 889      True       1    male  26.0      0      0  30.0000        C   First
# 890     False       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.dropna(subset=['age', 'deck'])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1        True       1  female  38.0      1      0  71.2833        C  First
# 3        True       1  female  35.0      1      0  53.1000        S  First
# 6       False       1    male  54.0      0      0  51.8625        S  First
# 10       True       3  female   4.0      1      1  16.7000        S  Third
# 11       True       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871      True       1  female  47.0      1      1  52.5542        S  First
# 872     False       1    male  33.0      0      0   5.0000        S  First
# 879      True       1  female  56.0      0      1  83.1583        C  First
# 887      True       1  female  19.0      0      0  30.0000        S  First
# 889      True       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.dropna(subset=['age', 'deck', 'embark_town'])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1        True       1  female  38.0      1      0  71.2833        C  First
# 3        True       1  female  35.0      1      0  53.1000        S  First
# 6       False       1    male  54.0      0      0  51.8625        S  First
# 10       True       3  female   4.0      1      1  16.7000        S  Third
# 11       True       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871      True       1  female  47.0      1      1  52.5542        S  First
# 872     False       1    male  33.0      0      0   5.0000        S  First
# 879      True       1  female  56.0      0      1  83.1583        C  First
# 887      True       1  female  19.0      0      0  30.0000        S  First
# 889      True       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ### Filling NaN values

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
age_median = titanic.age.median(skipna=True)
print(f"Age median: {age_median}")


updated_age_col = titanic.age.fillna(age_median)
updated_age_col
# Out:
# Age median: 28.0
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
updated_age_col.median()
# Out:
# 28.0

# %%
titanic.deck.head()
# Out:
# 0    NaN
# 1      C
# 2    NaN
# 3      C
# 4    NaN
# Name: deck, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
titanic.deck.tail()
# Out:
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: deck, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
titanic.deck.ffill()
# Out:
# 0      NaN
# 1        C
# 2        C
# 3        C
# 4        C
#       ...
# 886      C
# 887      B
# 888      B
# 889      C
# 890      C
# Name: deck, Length: 891, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
titanic.age.interpolate()
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    22.5
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
(titanic.isna().sum() / len(titanic)) * 100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %% [markdown]
# ## Group Based Summary

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0     False       3    male  22.0      1      0   7.2500        S  Third
# 1      True       1  female  38.0      1      0  71.2833        C  First
# 2      True       3  female  26.0      0      0   7.9250        S  Third
# 3      True       1  female  35.0      1      0  53.1000        S  First
# 4     False       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no      0
# 1  woman       False    C    Cherbourg   yes      0
# 2  woman       False  NaN  Southampton   yes      1
# 3  woman       False    C  Southampton   yes      0
# 4    man        True  NaN  Southampton    no      1

# %%
titanic.groupby('survived')['age'].median()
# Out:
# survived
# False    28.0
# True     28.0
# Name: age, dtype: float64

# %%
titanic.groupby('survived')['age'].agg(['min', 'max', 'mean'])
# Out:
#            min   max       mean
# survived
# False     1.00  74.0  30.626179
# True      0.42  80.0  28.343690

# %%
titanic['average_age'] = titanic.groupby('survived')['age'].transform('mean')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0     False       3    male  22.0      1      0   7.2500        S  Third
# 1      True       1  female  38.0      1      0  71.2833        C  First
# 2      True       3  female  26.0      0      0   7.9250        S  Third
# 3      True       1  female  35.0      1      0  53.1000        S  First
# 4     False       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  average_age
# 0    man        True  NaN  Southampton    no      0    30.626179
# 1  woman       False    C    Cherbourg   yes      0    28.343690
# 2  woman       False  NaN  Southampton   yes      1    28.343690
# 3  woman       False    C  Southampton   yes      0    28.343690
# 4    man        True  NaN  Southampton    no      1    30.626179

# %%
titanic.pivot_table(
    index='survived',
    values=['age', 'alone'],
    aggfunc={'age': 'mean', 'alone': 'max'}
)
# Out:
#                 age  alone
# survived
# False     30.626179      1
# True      28.343690      1

# %% [markdown]
# <center><b>Thanks</b></center>
