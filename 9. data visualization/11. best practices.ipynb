# %% [markdown]
# # **9. Data Visualization (with Pandas)**

# %% [markdown]
# ## **11. Customization Options (Basic)**

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ### 📌 1. What It Does and When to Use
#
# **Customization options** refer to visual modifications you can apply to your time series plots (created using pandas or Matplotlib) to improve readability, highlight patterns, and make your plots aesthetically pleasing and informative.
#
# ✅ Use **customization** when:
#
# * You want to tailor your visuals for specific audiences.
# * You need to highlight key trends, periods, or comparisons.
# * You're preparing plots for reports or dashboards.

# %% [markdown]
# ## 🛠️ 2. Syntax and Core Parameters
#
# Most customization is applied using Matplotlib functions that are either directly accessible through `pandas.plot()` or by calling `plt` from `matplotlib.pyplot`.
#
# ### General Syntax (for customization)
#
# ```python
# df.plot(
#     title='Title Here',
#     xlabel='X Axis Label',
#     ylabel='Y Axis Label',
#     figsize=(10, 5),
#     grid=True,
#     color='green',
#     linestyle='--',
#     marker='o'
# )
# ```
#
# Or using Matplotlib directly:
#
# ```python
# plt.plot(df.index, df['column'], color='red', linewidth=2, linestyle='-.')
# plt.title('Your Title')
# plt.xlabel('Date')
# plt.ylabel('Values')
# plt.grid(True)
# plt.xticks(rotation=45)
# plt.legend(['Series Name'])
# plt.show()
# ```

# %% [markdown]
# ## 🧰 3. Different Techniques (with Variations)
#
# ### 🔹 a. Titles and Axis Labels
#
# ```python
# plt.title('Daily Sales Over Time')
# plt.xlabel('Date')
# plt.ylabel('Sales')
# ```
#
# ### 🔹 b. Figure Size
#
# ```python
# plt.figure(figsize=(12, 6))
# ```
#
# ### 🔹 c. Line Style and Color
#
# ```python
# plt.plot(df.index, df['sales'], color='purple', linestyle='--', linewidth=2)
# ```
#
# ### 🔹 d. Grid Lines
#
# ```python
# plt.grid(True)
# ```
#
# ### 🔹 e. Markers
#
# ```python
# plt.plot(df.index, df['sales'], marker='o', markersize=5)
# ```
#
# ### 🔹 f. Legend
#
# ```python
# plt.legend(['Sales'])
# ```
#
# ### 🔹 g. Date Formatting
#
# Use `DateFormatter` from `matplotlib.dates` for better control:
#
# ```python
# import matplotlib.dates as mdates
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
# plt.gcf().autofmt_xdate()  # Auto-rotate date labels
# ```
#
# ### 🔹 h. Tick Rotation
#
# ```python
# plt.xticks(rotation=45)
# ```
#
# ### 🔹 i. Colors and Styles
#
# Use pandas’ support:
#
# ```python
# df.plot(color='orange', style='--')
# ```
#
# Or use a seaborn/matplotlib color palette:
#
# ```python
# import seaborn as sns
# colors = sns.color_palette("husl", 8)
# df.plot(color=colors)
# ```

# %% [markdown]
# ## 📊 4. Understanding Each Technique with Examples

# %%
# Simulated time series data
date_range = pd.date_range(start='2023-01-01', periods=30)
df = pd.DataFrame({
    'sales': np.random.randint(100, 200, size=30)
}, index=date_range)

df
# Out:
#             sales
# 2023-01-01    147
# 2023-01-02    111
# 2023-01-03    105
# 2023-01-04    141
# 2023-01-05    182
# 2023-01-06    196
# 2023-01-07    153
# 2023-01-08    133
# 2023-01-09    190
# 2023-01-10    182
# 2023-01-11    176
# 2023-01-12    134
# 2023-01-13    113
# 2023-01-14    128
# 2023-01-15    103
# 2023-01-16    108
# 2023-01-17    188
# 2023-01-18    193
# 2023-01-19    170
# 2023-01-20    182
# 2023-01-21    155
# 2023-01-22    156
# 2023-01-23    146
# 2023-01-24    135
# 2023-01-25    116
# 2023-01-26    198
# 2023-01-27    159
# 2023-01-28    124
# 2023-01-29    146
# 2023-01-30    119

# %% [markdown]
# ### Example 1: Basic Customized Plot

# %%
plt.figure(figsize=(10, 5))
plt.plot(df.index, df['sales'], color='darkblue', linestyle='--', marker='o')
plt.title('Daily Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Sales Units')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend(['Sales'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Example 2: Custom Date Format and Tick Frequency

# %%
import matplotlib.dates as mdates

fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(df.index, df['sales'], color='teal', linewidth=2)

# Set major ticks every 5 days and format
ax.xaxis.set_major_locator(mdates.DayLocator(interval=5))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

plt.title('Sales Trend')
plt.xlabel('Date')
plt.ylabel('Units Sold')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ⚠️ 5. Common Pitfalls
#
# | Pitfall                        | Why It’s a Problem                    |
# | ------------------------------ | ------------------------------------- |
# | ❌ Forgetting `tight_layout()`  | Overlaps between labels and plot area |
# | ❌ Using small figure sizes     | Crowds plot elements                  |
# | ❌ No label/legend              | Viewers can't interpret the plot      |
# | ❌ Over-using colors or markers | Makes plot visually noisy             |
# | ❌ Ignoring date formatting     | Leads to cluttered x-axis             |

# %% [markdown]
# ## 🌍 6. Real-World Examples & Use Cases
#
# | Scenario                 | Customizations Used                                          |
# | ------------------------ | ------------------------------------------------------------ |
# | **Retail Dashboard**     | Add legends, large fonts, custom colors, and date formatting |
# | **Energy Usage Trends**  | Use grid lines, area plots with transparency (`alpha`)       |
# | **Financial Reporting**  | Custom tick frequency, bold titles, annotations for events   |
# | **Web Traffic Analysis** | Interactive hover + rotated date labels + tight layout       |

# %% [markdown]
# ### 🧾 Summary Checklist
#
# | Feature                       | Use It For                             |
# | ----------------------------- | -------------------------------------- |
# | `figsize`                     | Better layout for various screen sizes |
# | `title`, `xlabel`, `ylabel`   | Clear interpretation                   |
# | `color`, `style`, `marker`    | Emphasize series or patterns           |
# | `grid`                        | Easier value reading                   |
# | `legend()`                    | Labeling multiple lines                |
# | `xticks(rotation=45)`         | Prevent cluttered x-axis               |
# | `DateFormatter`, `DayLocator` | Fine control of date ticks             |

# %% [markdown]
# <center><b>Thanks</b></center>
